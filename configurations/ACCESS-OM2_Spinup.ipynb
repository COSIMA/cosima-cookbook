# %% [markdown]
# # ACCESS-OM2 1$^\circ$ Spinup
#
# This notebook analyses the model output from the November 2017 ACCESS-OM2 Pre-release, implemented at 1°.

# %% [markdown]
# ## Current Status
#
#
# |** Run Name** | **Forcing** | ** Run ** | ** Status **|
# |--------------|---------|-------------------------------------------------|-------------|
# |1deg_jra55v13_ryf9091_spinup_A | JRA55 V1.3 RYF9091|  Our default Repeat Year Forcing (RYF) case for 1990-1991.| Stopped at year 500.|
# |1deg_jra55v13_ryf8485_spinup_A | JRA55 V1.3 RYF8485|  An RYF8485 case with v1.3 forcing. | Stopped at year 500.|
# |1deg_jra55v13_ryf0304_spinup_A | JRA55 V1.3 RYF0304|  An RYF0304 case with v1.3 forcing. | Stopped at year 500.|
# | 1deg_core_nyf_spinup_A | CORE NYF | Fabio's CORE-NYF case | Done 100 years. |
# |1deg_jra55v13_ryf9091_RCP45 | JRA55 V1.3 RYF9091|  Our default Repeat Year Forcing (RYF) case for 1990-1991, with an 8W/m^2 downwelling longwave perturbation and a 1.5°C temperature perturbation.| Years 300-500.|
# |1deg_jra55v13_ryf8485_RCP45 | JRA55 V1.3 RYF8485|  An RYF8485 case with v1.3 forcing, with an 8W/m^2 downwelling longwave perturbation and a 1.5°C temperature perturbation. | Years 300-500.|
# |1deg_jra55v13_ryf0304_RCP45 | JRA55 V1.3 RYF0304|  An RYF0304 case with v1.3 forcing, with an 8W/m^2 downwelling longwave perturbation and a 1.5°C temperature perturbation. | Years 300-500.|
#
# ### Notes
#
# **Last updated 20 November 2017**

# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
# Out:
# netcdf_index loaded.

# %%
cc.build_index()
# Out:
# Files found but not yet indexed: 0
# No new .nc files found.
# True

# %% [markdown]
# ## Experiments

# %%
# This subset of cases are the important ones
esub = [
 '1deg_jra55v13_ryf9091_spinup_A',
 '1deg_jra55v13_ryf8485_spinup_A',
 '1deg_jra55v13_ryf0304_spinup_A',
 '1deg_core_nyf_spinup_A',
 '1deg_jra55v13_ryf9091_RCP45',
 '1deg_jra55v13_ryf8485_RCP45',
 '1deg_jra55v13_ryf0304_RCP45',
       ]

# %% [markdown]
# ## Wind Stress
# Just a simple plot showing zonally averaged zonal wind stress from each case.

# %%
cc.plots.wind_stress(esub)

# %% [markdown]
# ## Ocean Scalars
# The following series of plots shows global timeseries of key metrics.

# %%
variables = ['ke_tot',
             'temp_global_ave', 
             'salt_global_ave',
             'salt_surface_ave',
             'total_ocean_sfc_salt_flux_coupler',
             'eta_global']

# %%
cc.plots.annual_scalar(esub, variables)

# %% [markdown]
# # Transports

# %%
cc.plots.drake_passage(esub)

# %%
cc.plots.bering_strait(esub)

# %% [markdown]
# # Meridional Overturning Circulation

# %%
cc.plots.psi_avg(esub, 10, GM=True)

# %%
cc.plots.aabw(esub, GM=True)

# %%
cc.plots.amoc(esub, GM=True)

# %%
cc.plots.amoc_south(esub, GM=True)

# %% [markdown]
# # Sea Surface Temperature
# LH column shows SST, RH column shows difference from Year 1.

# %%
cc.plots.sea_surface_temperature(esub[:3])
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
cc.plots.sea_surface_salinity(esub[:3])
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %% [markdown]
# # Zonal Mean transects

# %%
cc.plots.zonal_mean(esub[:3],'temp')
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/dask/array/numpy_compat.py:45: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
cc.plots.zonal_mean(esub[:3],'salt')

# %%
cc.plots.zonal_mean(esub[4:],'temp')

# %%
cc.plots.zonal_mean(esub[4:],'salt')
