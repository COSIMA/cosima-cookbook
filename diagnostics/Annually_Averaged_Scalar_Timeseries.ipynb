# %% [markdown]
# # Annually Averaged Scalar Timeseries
#
# This notebook shows how we extract information from ocean_scalar to plot timeseries. The data are resampled onto annual averages.

# %% [markdown]
# **Firstly,** load in the required libraries:

# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
# Out:
# netcdf_index loaded.

# %% [markdown]
# **Next,** we show to plot a single variable from a single experiment. The variable is loaded using ```get_nc_variable```. Note that we reference dates to 1700, so that we can use pandas to ```resample``` the data onto annual frequency.

# %%
expt = '1deg_jra55v13_ryf9091_spinup_A'
variable = 'temp_global_ave'
darray = cc.get_nc_variable(expt,
                             'ocean_scalar.nc',
                             variable,
                             time_units='days since 1700-01-01')
annual_average = darray.resample('A', 'time').compute()
# Out:
# HBox(children=(IntProgress(value=0, description='get_nc_variable:: ', max=250), HTML(value='')))
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/ipykernel/__main__.py:7: DeprecationWarning:
# .resample() has been modified to defer calculations. Instead of passing 'dim' and 'how="mean", instead consider using .resample(time="A").mean()

# %% [markdown]
# **Then,** the data can be plotted as you see fit:

# %%
plt.figure(figsize=(8,5))
annual_average.plot()
plt.title(expt)
# Out:
# Text(0.5,1,'1deg_jra55v13_ryf9091_spinup_A')

# %% [markdown]
# **Finally,** if you are intending to incorporate this type of code into your notebook, you may like to use the pre-written ```annual_scalar``` function (see functions under ```cosima_cookbook/```). This function can handle multiple experiments and multiple variables as shown below.

# %%
esub = [ '1deg_jra55v13_ryf9091_spinup_A',
        '1deg_jra55_ryf9091_gfdl50',
       ]
variables = ['ke_tot', 
             'eta_global']
cc.plots.annual_scalar(esub, variables)
